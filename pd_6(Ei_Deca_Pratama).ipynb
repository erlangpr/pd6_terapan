# %% [markdown]
# <a href="https://colab.research.google.com/github/erlangpr/pd6_terapan/blob/main/pd_6(Ei_Deca_Pratama).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel ("Data_Alumni1.xlsx", 0)

# %%
df.isna().sum()
# Out:
# No                      0
# NIM                     0
# NAMA                    0
# TTL                     0
# FAKULTAS/KETRAMPILAN    0
# ALAMAT                  0
# TH.MASUK                0
# TH.LULUS                0
# STATUS                  0
# MASA_TUNGGU             0
# GAJI                    0
# TOEFL                   0
# IPK                     0
# dtype: int64

# %%
data = df.dropna()

# %%
data
# Out:
#     No       NIM                  NAMA                               TTL  \
# 0    1   9018263      Puguh Drajat E.P        Purworejo, 4 November 1989
# 3    4   9018269       Pandu Herwijaya         Lampung, 19 Desember 1990
# 5    6   9020026   Moh. Dadi Kurniawan         Savanajaya, 27 Maret 1992
# 6    7  12018060        Martin Sarlina              Lepak, 23 Maret 1994
# 7    8  11018022      Yan Adhi Permadi              Jepara, 22 juni 1993
# 8    9   9018212       Achicha Wahyuni           Yogyakarta, 3 juni 1991
# 9   10   9018301   Yayan Tisna Permadi      Purbalingga, 08 Oktober 1991
# 10  11  12022020        Muh. Rama dhai          Pekanbaru, 29 Maret 1992
# 11  12  12022038           Nurwahyuddi  Dili, timor-timur/ 13 April 1995
# 12  13  12019039          Agus Purnomo            Klaten, 2 Agustus 1992
# 13  14  11018111  M. Akhwan Zulfayandi          Teros, 12 September 1992
# 14  15   9018135   Yunita Tri Hernawai            Magelang, 20 Juni 1991
# ...

# %% [markdown]
# **Pembersihan data menggunakan *mean value.***

# %%
mean_toefl = data.TOEFL.mean()

# %%
mean_toefl
# Out:
# 419.7692307692308

# %%
mean_ipk = data.IPK.mean()

# %%
mean_ipk
# Out:
# 3.1561538461538463

# %%
mean_gaji = data.GAJI.mean()

# %%
mean_gaji
# Out:
# 1333131.609467457

# %%
mean_masatunggu = data.MASA_TUNGGU.mean()

# %%
mean_masatunggu
# Out:
# 1.9230769230769225

# %%
max_ipk = data.IPK.max()

# %%
data.IPK.max()
# Out:
# 3.62

# %%
data.IPK.min()
# Out:
# 2.99

# %%
data.GAJI.min()
# Out:
# 600000.0

# %%
data.MASA_TUNGGU.max()
# Out:
# 2.4

# %%
data.TOEFL.max()
# Out:
# 480.0

# %% [markdown]
# **Pembersihan data menggunakan *don’t care method.***

# %%
def_status = 'Mahasiswa'
df.STATUS.fillna(def_status, inplace = True)
df
# Out:
#     No       NIM                  NAMA                               TTL  \
# 0    1   9018263      Puguh Drajat E.P        Purworejo, 4 November 1989
# 1    2  12022030  Arsyad Cahya Subrata              Bantul, 21 juni 1994
# 2    3  12020021          Yesi Novela          Tempilang, 1 januari 1995
# 3    4   9018269       Pandu Herwijaya         Lampung, 19 Desember 1990
# 4    5   9018109        Anjar Prasetyo        Gunungkidul, 27 April 1991
# 5    6   9020026   Moh. Dadi Kurniawan         Savanajaya, 27 Maret 1992
# 6    7  12018060        Martin Sarlina              Lepak, 23 Maret 1994
# 7    8  11018022      Yan Adhi Permadi              Jepara, 22 juni 1993
# 8    9   9018212       Achicha Wahyuni           Yogyakarta, 3 juni 1991
# 9   10   9018301   Yayan Tisna Permadi      Purbalingga, 08 Oktober 1991
# 10  11  12022020        Muh. Rama dhai          Pekanbaru, 29 Maret 1992
# 11  12  12022038           Nurwahyuddi  Dili, timor-timur/ 13 April 1995
# ...

# %%
from google.colab import files
df.to_csv('PD_6.csv')
files.download('pd_6.csv')

# %%
df.isna().sum()
# Out:
# No                      0
# NIM                     0
# NAMA                    0
# TTL                     0
# FAKULTAS/KETRAMPILAN    0
# ALAMAT                  0
# TH.MASUK                0
# TH.LULUS                0
# STATUS                  0
# MASA_TUNGGU             0
# GAJI                    0
# TOEFL                   0
# IPK                     0
# dtype: int64

# %%
data = df.dropna()
data
# Out:
#     No       NIM                  NAMA                               TTL  \
# 0    1   9018263      Puguh Drajat E.P        Purworejo, 4 November 1989
# 1    2  12022030  Arsyad Cahya Subrata              Bantul, 21 juni 1994
# 2    3  12020021          Yesi Novela          Tempilang, 1 januari 1995
# 3    4   9018269       Pandu Herwijaya         Lampung, 19 Desember 1990
# 4    5   9018109        Anjar Prasetyo        Gunungkidul, 27 April 1991
# 5    6   9020026   Moh. Dadi Kurniawan         Savanajaya, 27 Maret 1992
# 6    7  12018060        Martin Sarlina              Lepak, 23 Maret 1994
# 7    8  11018022      Yan Adhi Permadi              Jepara, 22 juni 1993
# 8    9   9018212       Achicha Wahyuni           Yogyakarta, 3 juni 1991
# 9   10   9018301   Yayan Tisna Permadi      Purbalingga, 08 Oktober 1991
# 10  11  12022020        Muh. Rama dhai          Pekanbaru, 29 Maret 1992
# 11  12  12022038           Nurwahyuddi  Dili, timor-timur/ 13 April 1995
# ...
